# %%
import argparse
from datetime import datetime
import hashlib
import os.path
import os
import random
import re
import sys
import tarfile
from enum import Enum
import numpy as np
from six.moves import urllib
import tensorflow as tf
import cv2

from tensorflow.contrib.quantize.python import quant_ops
from tensorflow.python.framework import graph_util
from tensorflow.python.framework import tensor_shape
from tensorflow.python.platform import gfile
from tensorflow.python.util import compat

import sys
import time

# These are all parameters that are tied to the particular model architecture
# we're using for Inception v3. These include things like tensor names and their
# sizes. If you want to adapt this script to work with another model, you will
# need to update these to reflect the values in the network you're using.
MAX_NUM_IMAGES_PER_CLASS = 2 ** 27 - 1  # ~134M

# %%
NUM_IMG = 700
INTERVAL = 0.2 * 1000
TYPE = 'fruits/apple'
DIM = (round(1280.0*0.5), round(720.0*0.5))

cap = cv2.VideoCapture(0)
init = time.time()*1000
n = 0
os.makedirs(TYPE, exist_ok=True)

while(True):
    curr = time.time()*1000
    if curr - init < INTERVAL:
        continue   
    n += 1
    init = curr
    
    # Capture frame-by-frame
    ret, frame = cap.read()
    # Our operations on the frame come here
    img = cv2.cvtColor(frame, cv2.COLOR_RGB2RGBA)

    # perform the actual resizing of the image and show it
    img = cv2.resize(img, DIM, interpolation = cv2.INTER_AREA)
    
    # Display the resulting frame
    cv2.imshow('frame', img)
    cv2.imwrite('%s/%s.jpg' % (TYPE,str(curr)), img)
    cv2.waitKey(1) 

    if n > NUM_IMG:
        break

print('ENDING')
# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# ENDING

# %%
class F:
    image_dir = 'fruits' #'fruits' #'flower_photos'
    model_dir = 'inception_dir'
    bottleneck_dir = 'tmp/bottleneck'
    final_tensor_name = 'final_result'
    summaries_dir = 'tmp/retrain_logs'
    architecture = 'inception_v3'
    how_many_training_steps = 4000
    train_batch_size = 100
    test_batch_size = -1 # A value of -1 causes the entire test set to be used, which leads to more stable results across runs.\
    eval_step_interval = 10 #How often to evaluate the training results.
    validation_batch_size = 100
    intermediate_store_frequency = 0 #How many steps to store intermediate graph. If "0" then will not store.\
    intermediate_output_graphs_dir = 'tmp/intermediate_graph/'
    print_misclassified_test_images = False # Whether to print out a list of all misclassified test images
    output_graph = 'tmp/output_graph.pb'
    output_labels = 'tmp/output_labels.txt'
    learning_rate = 0.01
    flip_left_right = False #Whether to randomly flip half of the training images horizontally
    random_crop = 0 #A percentage determining how much of a margin to randomly crop off the training images.\
    random_scale = 0 # A percentage determining how much to randomly scale up the size of the training images by.\
    random_brightness = 0 #A percentage determining how much to randomly multiply the training image input pixels up or down by.\
    random_scale = 0 # A percentage determining how much to randomly scale up the size of the training images by.\
    random_crop = 0 # A percentage determining how much of a margin to randomly crop off the training images.\
FLAGS = F()

# %%
def create_image_lists(image_dir, testing_percentage, validation_percentage):
  """Builds a list of training images from the file system.
  Analyzes the sub folders in the image directory, splits them into stable
  training, testing, and validation sets, and returns a data structure
  describing the lists of images for each label and their paths.
  Args:
    image_dir: String path to a folder containing subfolders of images.
    testing_percentage: Integer percentage of the images to reserve for tests.
    validation_percentage: Integer percentage of images reserved for validation.
  Returns:
    A dictionary containing an entry for each label subfolder, with images split
    into training, testing, and validation sets within each label.
  """
  if not gfile.Exists(image_dir):
    tf.logging.error("Image directory '" + image_dir + "' not found.")
    return None
  result = {}
  sub_dirs = [x[0] for x in gfile.Walk(image_dir)]
  # The root directory comes first, so skip it.
  is_root_dir = True
  for sub_dir in sub_dirs:
    if is_root_dir:
      is_root_dir = False
      continue
    extensions = ['jpg', 'jpeg', 'JPG', 'JPEG']
    file_list = []
    dir_name = os.path.basename(sub_dir)
    if dir_name == image_dir:
      continue
    tf.logging.info("Looking for images in '" + dir_name + "'")
    for extension in extensions:
      file_glob = os.path.join(image_dir, dir_name, '*.' + extension)
      file_list.extend(gfile.Glob(file_glob))
    if not file_list:
      tf.logging.warning('No files found')
      continue
    if len(file_list) < 20:
      tf.logging.warning(
          'WARNING: Folder has less than 20 images, which may cause issues.')
    elif len(file_list) > MAX_NUM_IMAGES_PER_CLASS:
      tf.logging.warning(
          'WARNING: Folder {} has more than {} images. Some images will '
          'never be selected.'.format(dir_name, MAX_NUM_IMAGES_PER_CLASS))
    label_name = re.sub(r'[^a-z0-9]+', ' ', dir_name.lower())
    training_images = []
    testing_images = []
    validation_images = []
    for file_name in file_list:
      base_name = os.path.basename(file_name)
      # We want to ignore anything after '_nohash_' in the file name when
      # deciding which set to put an image in, the data set creator has a way of
      # grouping photos that are close variations of each other. For example
      # this is used in the plant disease data set to group multiple pictures of
      # the same leaf.
      hash_name = re.sub(r'_nohash_.*$', '', file_name)
      # This looks a bit magical, but we need to decide whether this file should
      # go into the training, testing, or validation sets, and we want to keep
      # existing files in the same set even if more files are subsequently
      # added.
      # To do that, we need a stable way of deciding based on just the file name
      # itself, so we do a hash of that and then use that to generate a
      # probability value that we use to assign it.
      hash_name_hashed = hashlib.sha1(compat.as_bytes(hash_name)).hexdigest()
      percentage_hash = ((int(hash_name_hashed, 16) %
                          (MAX_NUM_IMAGES_PER_CLASS + 1)) *
                         (100.0 / MAX_NUM_IMAGES_PER_CLASS))
      if percentage_hash < validation_percentage:
        validation_images.append(base_name)
      elif percentage_hash < (testing_percentage + validation_percentage):
        testing_images.append(base_name)
      else:
        training_images.append(base_name)
    result[label_name] = {
        'dir': dir_name,
        'training': training_images,
        'testing': testing_images,
        'validation': validation_images,
    }
  return result

# %%
def create_model_info():
    is_quantized = False

    # pylint: disable=line-too-long
    data_url = 'http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz'
    # pylint: enable=line-too-long
    bottleneck_tensor_name = 'pool_3/_reshape:0'
    bottleneck_tensor_size = 2048
    input_width = 299
    input_height = 299
    input_depth = 3
    resized_input_tensor_name = 'Mul:0'
    model_file_name = 'classify_image_graph_def.pb'
    input_mean = 128
    input_std = 128

    return {
      'data_url': data_url,
      'bottleneck_tensor_name': bottleneck_tensor_name,
      'bottleneck_tensor_size': bottleneck_tensor_size,
      'input_width': input_width,
      'input_height': input_height,
      'input_depth': input_depth,
      'resized_input_tensor_name': resized_input_tensor_name,
      'model_file_name': model_file_name,
      'input_mean': input_mean,
      'input_std': input_std,
      'quantize_layer': is_quantized,
    }

# %%
def maybe_download_and_extract(data_url, dest_directory):
  if not os.path.exists(dest_directory):
    os.makedirs(dest_directory)
  filename = data_url.split('/')[-1]
  filepath = os.path.join(dest_directory, filename)
  if not os.path.exists(filepath):

    def _progress(count, block_size, total_size):
      sys.stdout.write('\r>> Downloading %s %.1f%%' %
                       (filename,
                        float(count * block_size) / float(total_size) * 100.0))
      sys.stdout.flush()

    filepath, _ = urllib.request.urlretrieve(data_url, filepath, _progress)
    print()
    statinfo = os.stat(filepath)
    tf.logging.info('Successfully downloaded', filename, statinfo.st_size,
                    'bytes.')
    print('Extracting file from ', filepath)
    tarfile.open(filepath, 'r:gz').extractall(dest_directory)
  else:
    print('Not extracting or downloading files, model already present in disk')

# %%
def create_model_graph(model_info, model_dir):
  """"Creates a graph from saved GraphDef file and returns a Graph object.
  Args:
    model_info: Dictionary containing information about the model architecture.
  Returns:
    Graph holding the trained Inception network, and various tensors we'll be
    manipulating.
  """
  with tf.Graph().as_default() as graph:
    model_path = os.path.join(model_dir, model_info['model_file_name'])
    print('Model path: ', model_path)
    with gfile.FastGFile(model_path, 'rb') as f:
      graph_def = tf.GraphDef()
      graph_def.ParseFromString(f.read())
      bottleneck_tensor, resized_input_tensor = (tf.import_graph_def(
          graph_def,
          name='',
          return_elements=[
              model_info['bottleneck_tensor_name'],
              model_info['resized_input_tensor_name'],
          ]))
  return graph, bottleneck_tensor, resized_input_tensor

# %% [markdown]
# COMPUTE INITIAL VALUES

# %%
model_info = create_model_info()
maybe_download_and_extract(model_info['data_url'], FLAGS.model_dir)
graph, bottleneck_tensor, resized_image_tensor = create_model_graph(model_info, 'inception_dir')

image_lists = create_image_lists(FLAGS.image_dir, 10,10)
# Out:
# Not extracting or downloading files, model already present in disk
# Model path:  inception_dir/classify_image_graph_def.pb
# INFO:tensorflow:Looking for images in 'apple'
# INFO:tensorflow:Looking for images in 'paprica'

# %%
def add_jpeg_decoding(input_width, input_height, input_depth, input_mean,
                      input_std):
  """Adds operations that perform JPEG decoding and resizing to the graph..
  Args:
    input_width: Desired width of the image fed into the recognizer graph.
    input_height: Desired width of the image fed into the recognizer graph.
    input_depth: Desired channels of the image fed into the recognizer graph.
    input_mean: Pixel value that should be zero in the image for the graph.
    input_std: How much to divide the pixel values by before recognition.
  Returns:
    Tensors for the node to feed JPEG data into, and the output of the
      preprocessing steps.
  """
  jpeg_data = tf.placeholder(tf.string, name='DecodeJPGInput')
  decoded_image = tf.image.decode_jpeg(jpeg_data, channels=input_depth)
  decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
  decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
  resize_shape = tf.stack([input_height, input_width])
  resize_shape_as_int = tf.cast(resize_shape, dtype=tf.int32)
  resized_image = tf.image.resize_bilinear(decoded_image_4d,
                                           resize_shape_as_int)
  offset_image = tf.subtract(resized_image, input_mean)
  mul_image = tf.multiply(offset_image, 1.0 / input_std)
  return jpeg_data, mul_image

# %%
def cache_bottlenecks(sess, image_lists, image_dir, bottleneck_dir,
                      jpeg_data_tensor, decoded_image_tensor,
                      resized_input_tensor, bottleneck_tensor, architecture):
  """Ensures all the training, testing, and validation bottlenecks are cached.
  Because we're likely to read the same image multiple times (if there are no
  distortions applied during training) it can speed things up a lot if we
  calculate the bottleneck layer values once for each image during
  preprocessing, and then just read those cached values repeatedly during
  training. Here we go through all the images we've found, calculate those
  values, and save them off.
  Args:
    sess: The current active TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    image_dir: Root folder string of the subfolders containing the training
    images.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    jpeg_data_tensor: Input tensor for jpeg data from file.
    decoded_image_tensor: The output of decoding and resizing the image.
    resized_input_tensor: The input node of the recognition graph.
    bottleneck_tensor: The penultimate output layer of the graph.
    architecture: The name of the model architecture.
  Returns:
    Nothing.
  """
  how_many_bottlenecks = 0
  ensure_dir_exists(bottleneck_dir)
  for label_name, label_lists in image_lists.items():
    for category in ['training', 'testing', 'validation']:
      category_list = label_lists[category]
      for index, unused_base_name in enumerate(category_list):
        get_or_create_bottleneck(
            sess, image_lists, label_name, index, image_dir, category,
            bottleneck_dir, jpeg_data_tensor, decoded_image_tensor,
            resized_input_tensor, bottleneck_tensor, architecture)

        how_many_bottlenecks += 1
        if how_many_bottlenecks % 100 == 0:
          tf.logging.info(
              str(how_many_bottlenecks) + ' bottleneck files created.')

# %%
def get_bottleneck_path(image_lists, label_name, index, bottleneck_dir,
                        category, architecture):
  """"Returns a path to a bottleneck file for a label at the given index.
  Args:
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Integer offset of the image we want. This will be moduloed by the
    available number of images for the label, so it can be arbitrarily large.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    category: Name string of set to pull images from - training, testing, or
    validation.
    architecture: The name of the model architecture.
  Returns:
    File system path string to an image that meets the requested parameters.
  """
  return get_image_path(image_lists, label_name, index, bottleneck_dir,
                        category) + '_' + architecture + '.txt'

# %%
def ensure_dir_exists(dir_name):
  """Makes sure the folder exists on disk.
  Args:
    dir_name: Path string to the folder we want to create.
  """
  if not os.path.exists(dir_name):
    os.makedirs(dir_name)

# %%
def get_or_create_bottleneck(sess, image_lists, label_name, index, image_dir,
                             category, bottleneck_dir, jpeg_data_tensor,
                             decoded_image_tensor, resized_input_tensor,
                             bottleneck_tensor, architecture):
  """Retrieves or calculates bottleneck values for an image.
  If a cached version of the bottleneck data exists on-disk, return that,
  otherwise calculate the data and save it to disk for future use.
  Args:
    sess: The current active TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Integer offset of the image we want. This will be modulo-ed by the
    available number of images for the label, so it can be arbitrarily large.
    image_dir: Root folder string of the subfolders containing the training
    images.
    category: Name string of which set to pull images from - training, testing,
    or validation.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    jpeg_data_tensor: The tensor to feed loaded jpeg data into.
    decoded_image_tensor: The output of decoding and resizing the image.
    resized_input_tensor: The input node of the recognition graph.
    bottleneck_tensor: The output tensor for the bottleneck values.
    architecture: The name of the model architecture.
  Returns:
    Numpy array of values produced by the bottleneck layer for the image.
  """
  label_lists = image_lists[label_name]
  sub_dir = label_lists['dir']
  sub_dir_path = os.path.join(bottleneck_dir, sub_dir)
  ensure_dir_exists(sub_dir_path)
  bottleneck_path = get_bottleneck_path(image_lists, label_name, index,
                                        bottleneck_dir, category, architecture)
  if not os.path.exists(bottleneck_path):
    create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           decoded_image_tensor, resized_input_tensor,
                           bottleneck_tensor)
  with open(bottleneck_path, 'r') as bottleneck_file:
    bottleneck_string = bottleneck_file.read()
  did_hit_error = False
  try:
    bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
  except ValueError:
    tf.logging.warning('Invalid float found, recreating bottleneck')
    did_hit_error = True
  if did_hit_error:
    create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           decoded_image_tensor, resized_input_tensor,
                           bottleneck_tensor)
    with open(bottleneck_path, 'r') as bottleneck_file:
      bottleneck_string = bottleneck_file.read()
    # Allow exceptions to propagate here, since they shouldn't happen after a
    # fresh creation
    bottleneck_values = [float(x) for x in bottleneck_string.split(',')]
  return bottleneck_values

# %%
def get_image_path(image_lists, label_name, index, image_dir, category):
  """"Returns a path to an image for a label at the given index.
  Args:
    image_lists: Dictionary of training images for each label.
    label_name: Label string we want to get an image for.
    index: Int offset of the image we want. This will be moduloed by the
    available number of images for the label, so it can be arbitrarily large.
    image_dir: Root folder string of the subfolders containing the training
    images.
    category: Name string of set to pull images from - training, testing, or
    validation.
  Returns:
    File system path string to an image that meets the requested parameters.
  """
  if label_name not in image_lists:
    tf.logging.fatal('Label does not exist %s.', label_name)
  label_lists = image_lists[label_name]
  if category not in label_lists:
    tf.logging.fatal('Category does not exist %s.', category)
  category_list = label_lists[category]
  if not category_list:
    tf.logging.fatal('Label %s has no images in the category %s.',
                     label_name, category)
  mod_index = index % len(category_list)
  base_name = category_list[mod_index]
  sub_dir = label_lists['dir']
  full_path = os.path.join(image_dir, sub_dir, base_name)
  return full_path

# %%
def create_bottleneck_file(bottleneck_path, image_lists, label_name, index,
                           image_dir, category, sess, jpeg_data_tensor,
                           decoded_image_tensor, resized_input_tensor,
                           bottleneck_tensor):
  """Create a single bottleneck file."""
  tf.logging.debug('Creating bottleneck at ' + bottleneck_path)
  image_path = get_image_path(image_lists, label_name, index,
                              image_dir, category)
  if not gfile.Exists(image_path):
    tf.logging.fatal('File does not exist %s', image_path)
  image_data = gfile.FastGFile(image_path, 'rb').read()
  try:
    bottleneck_values = run_bottleneck_on_image(
        sess, image_data, jpeg_data_tensor, decoded_image_tensor,
        resized_input_tensor, bottleneck_tensor)
  except Exception as e:
    raise RuntimeError('Error during processing file %s (%s)' % (image_path,
                                                                 str(e)))
  bottleneck_string = ','.join(str(x) for x in bottleneck_values)
  with open(bottleneck_path, 'w') as bottleneck_file:
    bottleneck_file.write(bottleneck_string)

# %%
def run_bottleneck_on_image(sess, image_data, image_data_tensor,
                            decoded_image_tensor, resized_input_tensor,
                            bottleneck_tensor):
  """Runs inference on an image to extract the 'bottleneck' summary layer.
  Args:
    sess: Current active TensorFlow Session.
    image_data: String of raw JPEG data.
    image_data_tensor: Input data layer in the graph.
    decoded_image_tensor: Output of initial image resizing and preprocessing.
    resized_input_tensor: The input node of the recognition graph.
    bottleneck_tensor: Layer before the final softmax.
  Returns:
    Numpy array of bottleneck values.
  """
  # First decode the JPEG image, resize it, and rescale the pixel values.
  resized_input_values = sess.run(decoded_image_tensor,
                                  {image_data_tensor: image_data})
  # Then run it through the recognition network.
  bottleneck_values = sess.run(bottleneck_tensor,
                               {resized_input_tensor: resized_input_values})
  bottleneck_values = np.squeeze(bottleneck_values)
  return bottleneck_values

# %%
def add_final_training_ops(class_count, final_tensor_name, bottleneck_tensor,
                           bottleneck_tensor_size, quantize_layer):
  """Adds a new softmax and fully-connected layer for training.
  We need to retrain the top layer to identify our new classes, so this function
  adds the right operations to the graph, along with some variables to hold the
  weights, and then sets up all the gradients for the backward pass.
  The set up for the softmax and fully-connected layers is based on:
  https://www.tensorflow.org/versions/master/tutorials/mnist/beginners/index.html
  Args:
    class_count: Integer of how many categories of things we're trying to
        recognize.
    final_tensor_name: Name string for the new final node that produces results.
    bottleneck_tensor: The output of the main CNN graph.
    bottleneck_tensor_size: How many entries in the bottleneck vector.
    quantize_layer: Boolean, specifying whether the newly added layer should be
        quantized.
  Returns:
    The tensors for the training and cross entropy results, and tensors for the
    bottleneck input and ground truth input.
  """
  with tf.name_scope('input'):
    bottleneck_input = tf.placeholder_with_default(
        bottleneck_tensor,
        shape=[None, bottleneck_tensor_size],
        name='BottleneckInputPlaceholder')

    ground_truth_input = tf.placeholder(
        tf.int64, [None], name='GroundTruthInput')

  # Organizing the following ops as `final_training_ops` so they're easier
  # to see in TensorBoard
  layer_name = 'final_training_ops'
  with tf.name_scope(layer_name):
    with tf.name_scope('weights'):
      initial_value = tf.truncated_normal(
          [bottleneck_tensor_size, class_count], stddev=0.001)
      layer_weights = tf.Variable(initial_value, name='final_weights')
      if quantize_layer:
        quantized_layer_weights = quant_ops.MovingAvgQuantize(
            layer_weights, is_training=True)
        variable_summaries(quantized_layer_weights)

      variable_summaries(layer_weights)
    with tf.name_scope('biases'):
      layer_biases = tf.Variable(tf.zeros([class_count]), name='final_biases')
      if quantize_layer:
        quantized_layer_biases = quant_ops.MovingAvgQuantize(
            layer_biases, is_training=True)
        variable_summaries(quantized_layer_biases)

      variable_summaries(layer_biases)

    with tf.name_scope('Wx_plus_b'):
      if quantize_layer:
        logits = tf.matmul(bottleneck_input,
                           quantized_layer_weights) + quantized_layer_biases
        logits = quant_ops.MovingAvgQuantize(
            logits,
            init_min=-32.0,
            init_max=32.0,
            is_training=True,
            num_bits=8,
            narrow_range=False,
            ema_decay=0.5)
        tf.summary.histogram('pre_activations', logits)
      else:
        logits = tf.matmul(bottleneck_input, layer_weights) + layer_biases
        tf.summary.histogram('pre_activations', logits)

  final_tensor = tf.nn.softmax(logits, name=final_tensor_name)

  tf.summary.histogram('activations', final_tensor)

  with tf.name_scope('cross_entropy'):
    cross_entropy_mean = tf.losses.sparse_softmax_cross_entropy(
        labels=ground_truth_input, logits=logits)

  tf.summary.scalar('cross_entropy', cross_entropy_mean)

  with tf.name_scope('train'):
    optimizer = tf.train.GradientDescentOptimizer(FLAGS.learning_rate)
    train_step = optimizer.minimize(cross_entropy_mean)

  return (train_step, cross_entropy_mean, bottleneck_input, ground_truth_input,
          final_tensor)

# %%
def variable_summaries(var):
  """Attach a lot of summaries to a Tensor (for TensorBoard visualization)."""
  with tf.name_scope('summaries'):
    mean = tf.reduce_mean(var)
    tf.summary.scalar('mean', mean)
    with tf.name_scope('stddev'):
      stddev = tf.sqrt(tf.reduce_mean(tf.square(var - mean)))
    tf.summary.scalar('stddev', stddev)
    tf.summary.scalar('max', tf.reduce_max(var))
    tf.summary.scalar('min', tf.reduce_min(var))
    tf.summary.histogram('histogram', var)

# %%
def add_evaluation_step(result_tensor, ground_truth_tensor):
  """Inserts the operations we need to evaluate the accuracy of our results.
  Args:
    result_tensor: The new final node that produces results.
    ground_truth_tensor: The node we feed ground truth data
    into.
  Returns:
    Tuple of (evaluation step, prediction).
  """
  with tf.name_scope('accuracy'):
    with tf.name_scope('correct_prediction'):
      prediction = tf.argmax(result_tensor, 1)
      correct_prediction = tf.equal(prediction, ground_truth_tensor)
    with tf.name_scope('accuracy'):
      evaluation_step = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
  tf.summary.scalar('accuracy', evaluation_step)
  return evaluation_step, prediction

# %%
def should_distort_images(flip_left_right, random_crop, random_scale,
                          random_brightness):
  """Whether any distortions are enabled, from the input flags.
  Args:
    flip_left_right: Boolean whether to randomly mirror images horizontally.
    random_crop: Integer percentage setting the total margin used around the
    crop box.
    random_scale: Integer percentage of how much to vary the scale by.
    random_brightness: Integer range to randomly multiply the pixel values by.
  Returns:
    Boolean value indicating whether any distortions should be applied.
  """
  return (flip_left_right or (random_crop != 0) or (random_scale != 0) or
          (random_brightness != 0))

# %%
def get_random_cached_bottlenecks(sess, image_lists, how_many, category,
                                  bottleneck_dir, image_dir, jpeg_data_tensor,
                                  decoded_image_tensor, resized_input_tensor,
                                  bottleneck_tensor, architecture):
  """Retrieves bottleneck values for cached images.
  If no distortions are being applied, this function can retrieve the cached
  bottleneck values directly from disk for images. It picks a random set of
  images from the specified category.
  Args:
    sess: Current TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    how_many: If positive, a random sample of this size will be chosen.
    If negative, all bottlenecks will be retrieved.
    category: Name string of which set to pull from - training, testing, or
    validation.
    bottleneck_dir: Folder string holding cached files of bottleneck values.
    image_dir: Root folder string of the subfolders containing the training
    images.
    jpeg_data_tensor: The layer to feed jpeg image data into.
    decoded_image_tensor: The output of decoding and resizing the image.
    resized_input_tensor: The input node of the recognition graph.
    bottleneck_tensor: The bottleneck output layer of the CNN graph.
    architecture: The name of the model architecture.
  Returns:
    List of bottleneck arrays, their corresponding ground truths, and the
    relevant filenames.
  """
  class_count = len(image_lists.keys())
  bottlenecks = []
  ground_truths = []
  filenames = []
  if how_many >= 0:
    # Retrieve a random sample of bottlenecks.
    for unused_i in range(how_many):
      label_index = random.randrange(class_count)
      label_name = list(image_lists.keys())[label_index]
      image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
      image_name = get_image_path(image_lists, label_name, image_index,
                                  image_dir, category)
      bottleneck = get_or_create_bottleneck(
          sess, image_lists, label_name, image_index, image_dir, category,
          bottleneck_dir, jpeg_data_tensor, decoded_image_tensor,
          resized_input_tensor, bottleneck_tensor, architecture)
      bottlenecks.append(bottleneck)
      ground_truths.append(label_index)
      filenames.append(image_name)
  else:
    # Retrieve all bottlenecks.
    for label_index, label_name in enumerate(image_lists.keys()):
      for image_index, image_name in enumerate(
          image_lists[label_name][category]):
        image_name = get_image_path(image_lists, label_name, image_index,
                                    image_dir, category)
        bottleneck = get_or_create_bottleneck(
            sess, image_lists, label_name, image_index, image_dir, category,
            bottleneck_dir, jpeg_data_tensor, decoded_image_tensor,
            resized_input_tensor, bottleneck_tensor, architecture)
        bottlenecks.append(bottleneck)
        ground_truths.append(label_index)
        filenames.append(image_name)
  return bottlenecks, ground_truths, filenames

# %%
def save_graph_to_file(sess, graph, graph_file_name):
  output_graph_def = graph_util.convert_variables_to_constants(
      sess, graph.as_graph_def(), [FLAGS.final_tensor_name])

  with gfile.FastGFile(graph_file_name, 'wb') as f:
    f.write(output_graph_def.SerializeToString())
  return

# %%
def get_random_distorted_bottlenecks(
    sess, image_lists, how_many, category, image_dir, input_jpeg_tensor,
    distorted_image, resized_input_tensor, bottleneck_tensor):
  """Retrieves bottleneck values for training images, after distortions.
  If we're training with distortions like crops, scales, or flips, we have to
  recalculate the full model for every image, and so we can't use cached
  bottleneck values. Instead we find random images for the requested category,
  run them through the distortion graph, and then the full graph to get the
  bottleneck results for each.
  Args:
    sess: Current TensorFlow Session.
    image_lists: Dictionary of training images for each label.
    how_many: The integer number of bottleneck values to return.
    category: Name string of which set of images to fetch - training, testing,
    or validation.
    image_dir: Root folder string of the subfolders containing the training
    images.
    input_jpeg_tensor: The input layer we feed the image data to.
    distorted_image: The output node of the distortion graph.
    resized_input_tensor: The input node of the recognition graph.
    bottleneck_tensor: The bottleneck output layer of the CNN graph.
  Returns:
    List of bottleneck arrays and their corresponding ground truths.
  """
  class_count = len(image_lists.keys())
  bottlenecks = []
  ground_truths = []
  for unused_i in range(how_many):
    label_index = random.randrange(class_count)
    label_name = list(image_lists.keys())[label_index]
    image_index = random.randrange(MAX_NUM_IMAGES_PER_CLASS + 1)
    image_path = get_image_path(image_lists, label_name, image_index, image_dir,
                                category)
    if not gfile.Exists(image_path):
      tf.logging.fatal('File does not exist %s', image_path)
    jpeg_data = gfile.FastGFile(image_path, 'rb').read()
    # Note that we materialize the distorted_image_data as a numpy array before
    # sending running inference on the image. This involves 2 memory copies and
    # might be optimized in other implementations.
    distorted_image_data = sess.run(distorted_image,
                                    {input_jpeg_tensor: jpeg_data})
    bottleneck_values = sess.run(bottleneck_tensor,
                                 {resized_input_tensor: distorted_image_data})
    bottleneck_values = np.squeeze(bottleneck_values)
    bottlenecks.append(bottleneck_values)
    ground_truths.append(label_index)
  return bottlenecks, ground_truths

# %%
def add_input_distortions(flip_left_right, random_crop, random_scale,
                          random_brightness, input_width, input_height,
                          input_depth, input_mean, input_std):
  """Creates the operations to apply the specified distortions.
  During training it can help to improve the results if we run the images
  through simple distortions like crops, scales, and flips. These reflect the
  kind of variations we expect in the real world, and so can help train the
  model to cope with natural data more effectively. Here we take the supplied
  parameters and construct a network of operations to apply them to an image.
  Cropping
  ~~~~~~~~
  Cropping is done by placing a bounding box at a random position in the full
  image. The cropping parameter controls the size of that box relative to the
  input image. If it's zero, then the box is the same size as the input and no
  cropping is performed. If the value is 50%, then the crop box will be half the
  width and height of the input. In a diagram it looks like this:
  <       width         >
  +---------------------+
  |                     |
  |   width - crop%     |
  |    <      >         |
  |    +------+         |
  |    |      |         |
  |    |      |         |
  |    |      |         |
  |    +------+         |
  |                     |
  |                     |
  +---------------------+
  Scaling
  ~~~~~~~
  Scaling is a lot like cropping, except that the bounding box is always
  centered and its size varies randomly within the given range. For example if
  the scale percentage is zero, then the bounding box is the same size as the
  input and no scaling is applied. If it's 50%, then the bounding box will be in
  a random range between half the width and height and full size.
  Args:
    flip_left_right: Boolean whether to randomly mirror images horizontally.
    random_crop: Integer percentage setting the total margin used around the
    crop box.
    random_scale: Integer percentage of how much to vary the scale by.
    random_brightness: Integer range to randomly multiply the pixel values by.
    graph.
    input_width: Horizontal size of expected input image to model.
    input_height: Vertical size of expected input image to model.
    input_depth: How many channels the expected input image should have.
    input_mean: Pixel value that should be zero in the image for the graph.
    input_std: How much to divide the pixel values by before recognition.
  Returns:
    The jpeg input layer and the distorted result tensor.
  """

  jpeg_data = tf.placeholder(tf.string, name='DistortJPGInput')
  decoded_image = tf.image.decode_jpeg(jpeg_data, channels=input_depth)
  decoded_image_as_float = tf.cast(decoded_image, dtype=tf.float32)
  decoded_image_4d = tf.expand_dims(decoded_image_as_float, 0)
  margin_scale = 1.0 + (random_crop / 100.0)
  resize_scale = 1.0 + (random_scale / 100.0)
  margin_scale_value = tf.constant(margin_scale)
  resize_scale_value = tf.random_uniform(tensor_shape.scalar(),
                                         minval=1.0,
                                         maxval=resize_scale)
  scale_value = tf.multiply(margin_scale_value, resize_scale_value)
  precrop_width = tf.multiply(scale_value, input_width)
  precrop_height = tf.multiply(scale_value, input_height)
  precrop_shape = tf.stack([precrop_height, precrop_width])
  precrop_shape_as_int = tf.cast(precrop_shape, dtype=tf.int32)
  precropped_image = tf.image.resize_bilinear(decoded_image_4d,
                                              precrop_shape_as_int)
  precropped_image_3d = tf.squeeze(precropped_image, squeeze_dims=[0])
  cropped_image = tf.random_crop(precropped_image_3d,
                                 [input_height, input_width, input_depth])
  if flip_left_right:
    flipped_image = tf.image.random_flip_left_right(cropped_image)
  else:
    flipped_image = cropped_image
  brightness_min = 1.0 - (random_brightness / 100.0)
  brightness_max = 1.0 + (random_brightness / 100.0)
  brightness_value = tf.random_uniform(tensor_shape.scalar(),
                                       minval=brightness_min,
                                       maxval=brightness_max)
  brightened_image = tf.multiply(flipped_image, brightness_value)
  offset_image = tf.subtract(brightened_image, input_mean)
  mul_image = tf.multiply(offset_image, 1.0 / input_std)
  distort_result = tf.expand_dims(mul_image, 0, name='DistortResult')
  return jpeg_data, distort_result

# %% [markdown]
# COUNT MAIN THINGS

# %%
do_distort_images = should_distort_images(
    FLAGS.flip_left_right, FLAGS.random_crop, FLAGS.random_scale,
    FLAGS.random_brightness)

with tf.Session(graph=graph) as sess:
    # Set up the image decoding sub-graph.
    jpeg_data_tensor, decoded_image_tensor = add_jpeg_decoding(
        model_info['input_width'], model_info['input_height'],
        model_info['input_depth'], model_info['input_mean'],
        model_info['input_std'])

    if do_distort_images:
        # We will be applying distortions, so setup the operations we'll need.
        (distorted_jpeg_data_tensor,
         distorted_image_tensor) = add_input_distortions(
            FLAGS.flip_left_right, FLAGS.random_crop, FLAGS.random_scale,
            FLAGS.random_brightness, model_info['input_width'],
            model_info['input_height'], model_info['input_depth'],
            model_info['input_mean'], model_info['input_std'])
    else:
        # We'll make sure we've calculated the 'bottleneck' image summaries and
        # cached them on disk.
        cache_bottlenecks(sess, image_lists, FLAGS.image_dir,
                          FLAGS.bottleneck_dir, jpeg_data_tensor,
                          decoded_image_tensor, resized_image_tensor,
                          bottleneck_tensor, FLAGS.architecture)

    # Add the new layer that we'll be training.
    (train_step, cross_entropy, bottleneck_input, ground_truth_input,
     final_tensor) = add_final_training_ops(
        len(image_lists.keys()), FLAGS.final_tensor_name, bottleneck_tensor,
        model_info['bottleneck_tensor_size'], model_info['quantize_layer'])

    # Create the operations we need to evaluate the accuracy of our new layer.
    evaluation_step, prediction = add_evaluation_step(
        final_tensor, ground_truth_input)

    # Merge all the summaries and write them out to the summaries_dir
    merged = tf.summary.merge_all()
    train_writer = tf.summary.FileWriter(FLAGS.summaries_dir + '/train',
                                         sess.graph)

    validation_writer = tf.summary.FileWriter(
        FLAGS.summaries_dir + '/validation')

    # Set up all our weights to their initial default values.
    init = tf.global_variables_initializer()
    sess.run(init)

    # Run the training for as many cycles as requested on the command line.
    for i in range(FLAGS.how_many_training_steps):
        # Get a batch of input bottleneck values, either calculated fresh every
        # time with distortions applied, or from the cache stored on disk.
        if do_distort_images:
            (train_bottlenecks,
             train_ground_truth) = get_random_distorted_bottlenecks(
                sess, image_lists, FLAGS.train_batch_size, 'training',
                FLAGS.image_dir, distorted_jpeg_data_tensor,
                distorted_image_tensor, resized_image_tensor, bottleneck_tensor)
        else:
            (train_bottlenecks,
             train_ground_truth, _) = get_random_cached_bottlenecks(
                sess, image_lists, FLAGS.train_batch_size, 'training',
                FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
                decoded_image_tensor, resized_image_tensor, bottleneck_tensor,
                FLAGS.architecture)
        # Feed the bottlenecks and ground truth into the graph, and run a training
        # step. Capture training summaries for TensorBoard with the `merged` op.
        train_summary, _ = sess.run(
            [merged, train_step],
            feed_dict={bottleneck_input: train_bottlenecks,
                       ground_truth_input: train_ground_truth})
        train_writer.add_summary(train_summary, i)

        # Every so often, print out how well the graph is training.
        is_last_step = (i + 1 == FLAGS.how_many_training_steps)
        if (i % FLAGS.eval_step_interval) == 0 or is_last_step:
            train_accuracy, cross_entropy_value = sess.run(
                [evaluation_step, cross_entropy],
                feed_dict={bottleneck_input: train_bottlenecks,
                           ground_truth_input: train_ground_truth})
            tf.logging.info('%s: Step %d: Train accuracy = %.1f%%' %
                            (datetime.now(), i, train_accuracy * 100))
            tf.logging.info('%s: Step %d: Cross entropy = %f' %
                            (datetime.now(), i, cross_entropy_value))
            validation_bottlenecks, validation_ground_truth, _ = (
                get_random_cached_bottlenecks(
                    sess, image_lists, FLAGS.validation_batch_size, 'validation',
                    FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
                    decoded_image_tensor, resized_image_tensor, bottleneck_tensor,
                    FLAGS.architecture))
            # Run a validation step and capture training summaries for TensorBoard
            # with the `merged` op.
            validation_summary, validation_accuracy = sess.run(
                [merged, evaluation_step],
                feed_dict={bottleneck_input: validation_bottlenecks,
                           ground_truth_input: validation_ground_truth})
            validation_writer.add_summary(validation_summary, i)
            tf.logging.info('%s: Step %d: Validation accuracy = %.1f%% (N=%d)' %
                            (datetime.now(), i, validation_accuracy * 100,
                             len(validation_bottlenecks)))

        # Store intermediate results
        intermediate_frequency = FLAGS.intermediate_store_frequency

        if (intermediate_frequency > 0 and (i % intermediate_frequency == 0)
                and i > 0):
            intermediate_file_name = (FLAGS.intermediate_output_graphs_dir +
                                      'intermediate_' + str(i) + '.pb')
            tf.logging.info('Save intermediate result to : ' +
                            intermediate_file_name)
            save_graph_to_file(sess, graph, intermediate_file_name)

    # We've completed all our training, so run a final test evaluation on
    # some new images we haven't used before.
    test_bottlenecks, test_ground_truth, test_filenames = (
        get_random_cached_bottlenecks(
            sess, image_lists, FLAGS.test_batch_size, 'testing',
            FLAGS.bottleneck_dir, FLAGS.image_dir, jpeg_data_tensor,
            decoded_image_tensor, resized_image_tensor, bottleneck_tensor,
            FLAGS.architecture))
    test_accuracy, predictions = sess.run(
        [evaluation_step, prediction],
        feed_dict={bottleneck_input: test_bottlenecks,
                   ground_truth_input: test_ground_truth})
    tf.logging.info('Final test accuracy = %.1f%% (N=%d)' %
                    (test_accuracy * 100, len(test_bottlenecks)))

    if FLAGS.print_misclassified_test_images:
        tf.logging.info('=== MISCLASSIFIED TEST IMAGES ===')
        for i, test_filename in enumerate(test_filenames):
            if predictions[i] != test_ground_truth[i]:
                tf.logging.info('%70s  %s' %
                                (test_filename,
                                 list(image_lists.keys())[predictions[i]]))

    # Write out the trained graph and labels with the weights stored as
    # constants.
    save_graph_to_file(sess, graph, FLAGS.output_graph)
    with gfile.FastGFile(FLAGS.output_labels, 'w') as f:
        f.write('\n'.join(image_lists.keys()) + '\n')
# Out:
# INFO:tensorflow:100 bottleneck files created.
# INFO:tensorflow:200 bottleneck files created.
# INFO:tensorflow:300 bottleneck files created.
# INFO:tensorflow:400 bottleneck files created.
# INFO:tensorflow:500 bottleneck files created.
# INFO:tensorflow:600 bottleneck files created.
# INFO:tensorflow:700 bottleneck files created.
# INFO:tensorflow:800 bottleneck files created.
# INFO:tensorflow:900 bottleneck files created.
# INFO:tensorflow:1000 bottleneck files created.
# INFO:tensorflow:1100 bottleneck files created.
# INFO:tensorflow:1200 bottleneck files created.
# INFO:tensorflow:1300 bottleneck files created.
# INFO:tensorflow:1400 bottleneck files created.
# INFO:tensorflow:2018-01-06 21:11:57.345861: Step 0: Train accuracy = 55.0%
# INFO:tensorflow:2018-01-06 21:11:57.347019: Step 0: Cross entropy = 0.616064
# INFO:tensorflow:2018-01-06 21:11:58.194022: Step 0: Validation accuracy = 46.0% (N=100)
# INFO:tensorflow:2018-01-06 21:11:58.798794: Step 10: Train accuracy = 98.0%
# INFO:tensorflow:2018-01-06 21:11:58.799820: Step 10: Cross entropy = 0.297136
# INFO:tensorflow:2018-01-06 21:11:58.865448: Step 10: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:11:59.473518: Step 20: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:11:59.474534: Step 20: Cross entropy = 0.205433
# INFO:tensorflow:2018-01-06 21:11:59.540976: Step 20: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:00.146427: Step 30: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:00.147432: Step 30: Cross entropy = 0.169406
# INFO:tensorflow:2018-01-06 21:12:00.210964: Step 30: Validation accuracy = 94.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:00.805160: Step 40: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:00.806198: Step 40: Cross entropy = 0.156468
# INFO:tensorflow:2018-01-06 21:12:00.871802: Step 40: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:01.472298: Step 50: Train accuracy = 95.0%
# INFO:tensorflow:2018-01-06 21:12:01.473330: Step 50: Cross entropy = 0.166020
# INFO:tensorflow:2018-01-06 21:12:01.537712: Step 50: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:02.146219: Step 60: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:02.147177: Step 60: Cross entropy = 0.133927
# INFO:tensorflow:2018-01-06 21:12:02.210128: Step 60: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:02.813095: Step 70: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:02.814095: Step 70: Cross entropy = 0.084507
# INFO:tensorflow:2018-01-06 21:12:02.875305: Step 70: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:03.477152: Step 80: Train accuracy = 98.0%
# INFO:tensorflow:2018-01-06 21:12:03.478092: Step 80: Cross entropy = 0.113618
# INFO:tensorflow:2018-01-06 21:12:03.539514: Step 80: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:04.143890: Step 90: Train accuracy = 97.0%
# INFO:tensorflow:2018-01-06 21:12:04.144963: Step 90: Cross entropy = 0.107757
# INFO:tensorflow:2018-01-06 21:12:04.207729: Step 90: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:04.801674: Step 100: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:04.802667: Step 100: Cross entropy = 0.072619
# INFO:tensorflow:2018-01-06 21:12:04.863935: Step 100: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:05.463622: Step 110: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:05.464645: Step 110: Cross entropy = 0.074928
# INFO:tensorflow:2018-01-06 21:12:05.528351: Step 110: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:06.125891: Step 120: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:06.126866: Step 120: Cross entropy = 0.076566
# INFO:tensorflow:2018-01-06 21:12:06.189361: Step 120: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:06.788280: Step 130: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:06.789286: Step 130: Cross entropy = 0.062521
# INFO:tensorflow:2018-01-06 21:12:06.852568: Step 130: Validation accuracy = 95.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:07.443071: Step 140: Train accuracy = 97.0%
# INFO:tensorflow:2018-01-06 21:12:07.444079: Step 140: Cross entropy = 0.088065
# INFO:tensorflow:2018-01-06 21:12:07.506507: Step 140: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:08.104322: Step 150: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:08.105337: Step 150: Cross entropy = 0.064485
# INFO:tensorflow:2018-01-06 21:12:08.168299: Step 150: Validation accuracy = 96.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:08.767118: Step 160: Train accuracy = 97.0%
# INFO:tensorflow:2018-01-06 21:12:08.768131: Step 160: Cross entropy = 0.073237
# INFO:tensorflow:2018-01-06 21:12:08.834044: Step 160: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:09.436090: Step 170: Train accuracy = 98.0%
# INFO:tensorflow:2018-01-06 21:12:09.437053: Step 170: Cross entropy = 0.068939
# INFO:tensorflow:2018-01-06 21:12:09.500400: Step 170: Validation accuracy = 95.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:10.102785: Step 180: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:10.103792: Step 180: Cross entropy = 0.054205
# INFO:tensorflow:2018-01-06 21:12:10.167161: Step 180: Validation accuracy = 95.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:10.772721: Step 190: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:10.773732: Step 190: Cross entropy = 0.043032
# INFO:tensorflow:2018-01-06 21:12:10.836926: Step 190: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:11.435413: Step 200: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:11.436543: Step 200: Cross entropy = 0.065141
# INFO:tensorflow:2018-01-06 21:12:11.499892: Step 200: Validation accuracy = 93.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:12.100417: Step 210: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:12.101412: Step 210: Cross entropy = 0.057746
# INFO:tensorflow:2018-01-06 21:12:12.165620: Step 210: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:12.773096: Step 220: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:12.774105: Step 220: Cross entropy = 0.052690
# INFO:tensorflow:2018-01-06 21:12:12.839910: Step 220: Validation accuracy = 96.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:13.438461: Step 230: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:13.439434: Step 230: Cross entropy = 0.044000
# INFO:tensorflow:2018-01-06 21:12:13.502869: Step 230: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:14.102685: Step 240: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:14.104439: Step 240: Cross entropy = 0.050724
# INFO:tensorflow:2018-01-06 21:12:14.171631: Step 240: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:14.782858: Step 250: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:14.783909: Step 250: Cross entropy = 0.051401
# INFO:tensorflow:2018-01-06 21:12:14.846914: Step 250: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:15.466105: Step 260: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:15.467238: Step 260: Cross entropy = 0.048423
# INFO:tensorflow:2018-01-06 21:12:15.539892: Step 260: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:16.207970: Step 270: Train accuracy = 97.0%
# INFO:tensorflow:2018-01-06 21:12:16.208988: Step 270: Cross entropy = 0.062015
# INFO:tensorflow:2018-01-06 21:12:16.272055: Step 270: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:16.867623: Step 280: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:16.868771: Step 280: Cross entropy = 0.041023
# INFO:tensorflow:2018-01-06 21:12:16.935212: Step 280: Validation accuracy = 96.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:17.536194: Step 290: Train accuracy = 98.0%
# INFO:tensorflow:2018-01-06 21:12:17.537235: Step 290: Cross entropy = 0.067655
# INFO:tensorflow:2018-01-06 21:12:17.598757: Step 290: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:18.200348: Step 300: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:18.201404: Step 300: Cross entropy = 0.045806
# INFO:tensorflow:2018-01-06 21:12:18.266121: Step 300: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:18.864510: Step 310: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:18.865516: Step 310: Cross entropy = 0.037150
# INFO:tensorflow:2018-01-06 21:12:18.927443: Step 310: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:19.524619: Step 320: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:19.525662: Step 320: Cross entropy = 0.047737
# INFO:tensorflow:2018-01-06 21:12:19.587056: Step 320: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:20.192253: Step 330: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:20.193291: Step 330: Cross entropy = 0.035918
# INFO:tensorflow:2018-01-06 21:12:20.256257: Step 330: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:20.860072: Step 340: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:20.861103: Step 340: Cross entropy = 0.043550
# INFO:tensorflow:2018-01-06 21:12:20.923747: Step 340: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:21.528225: Step 350: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:21.529365: Step 350: Cross entropy = 0.040932
# INFO:tensorflow:2018-01-06 21:12:21.592696: Step 350: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:22.187893: Step 360: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:22.188924: Step 360: Cross entropy = 0.030592
# INFO:tensorflow:2018-01-06 21:12:22.252158: Step 360: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:22.852419: Step 370: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:22.853432: Step 370: Cross entropy = 0.047776
# INFO:tensorflow:2018-01-06 21:12:22.919347: Step 370: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:23.517278: Step 380: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:23.518310: Step 380: Cross entropy = 0.039119
# INFO:tensorflow:2018-01-06 21:12:23.584146: Step 380: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:24.184453: Step 390: Train accuracy = 98.0%
# INFO:tensorflow:2018-01-06 21:12:24.185499: Step 390: Cross entropy = 0.039640
# INFO:tensorflow:2018-01-06 21:12:24.248286: Step 390: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:24.847402: Step 400: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:24.848409: Step 400: Cross entropy = 0.025942
# INFO:tensorflow:2018-01-06 21:12:24.911019: Step 400: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:25.506097: Step 410: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:25.507066: Step 410: Cross entropy = 0.026166
# INFO:tensorflow:2018-01-06 21:12:25.570121: Step 410: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:26.177911: Step 420: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:26.178902: Step 420: Cross entropy = 0.030315
# INFO:tensorflow:2018-01-06 21:12:26.239975: Step 420: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:26.840780: Step 430: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:26.841773: Step 430: Cross entropy = 0.040874
# INFO:tensorflow:2018-01-06 21:12:26.904170: Step 430: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:27.511191: Step 440: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:27.512223: Step 440: Cross entropy = 0.039314
# INFO:tensorflow:2018-01-06 21:12:27.573479: Step 440: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:28.179025: Step 450: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:28.180042: Step 450: Cross entropy = 0.019313
# INFO:tensorflow:2018-01-06 21:12:28.241113: Step 450: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:28.844186: Step 460: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:28.845213: Step 460: Cross entropy = 0.041848
# INFO:tensorflow:2018-01-06 21:12:28.908635: Step 460: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:29.532605: Step 470: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:29.533583: Step 470: Cross entropy = 0.036452
# INFO:tensorflow:2018-01-06 21:12:29.600536: Step 470: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:30.223031: Step 480: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:30.224025: Step 480: Cross entropy = 0.038545
# INFO:tensorflow:2018-01-06 21:12:30.286768: Step 480: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:30.889330: Step 490: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:30.890356: Step 490: Cross entropy = 0.039763
# INFO:tensorflow:2018-01-06 21:12:30.952199: Step 490: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:31.558332: Step 500: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:31.559303: Step 500: Cross entropy = 0.033878
# INFO:tensorflow:2018-01-06 21:12:31.621945: Step 500: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:32.233972: Step 510: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:32.234973: Step 510: Cross entropy = 0.027205
# INFO:tensorflow:2018-01-06 21:12:32.296652: Step 510: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:32.892279: Step 520: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:32.893246: Step 520: Cross entropy = 0.028584
# INFO:tensorflow:2018-01-06 21:12:32.956367: Step 520: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:33.564037: Step 530: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:33.565074: Step 530: Cross entropy = 0.025223
# INFO:tensorflow:2018-01-06 21:12:33.628014: Step 530: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:34.225810: Step 540: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:34.226800: Step 540: Cross entropy = 0.034485
# INFO:tensorflow:2018-01-06 21:12:34.289495: Step 540: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:34.886114: Step 550: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:34.887245: Step 550: Cross entropy = 0.037943
# INFO:tensorflow:2018-01-06 21:12:34.951343: Step 550: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:35.550143: Step 560: Train accuracy = 98.0%
# INFO:tensorflow:2018-01-06 21:12:35.551176: Step 560: Cross entropy = 0.040374
# INFO:tensorflow:2018-01-06 21:12:35.614333: Step 560: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:36.220012: Step 570: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:36.220982: Step 570: Cross entropy = 0.028569
# INFO:tensorflow:2018-01-06 21:12:36.285190: Step 570: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:36.880137: Step 580: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:36.881126: Step 580: Cross entropy = 0.030896
# INFO:tensorflow:2018-01-06 21:12:36.945025: Step 580: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:37.545261: Step 590: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:37.546257: Step 590: Cross entropy = 0.024680
# INFO:tensorflow:2018-01-06 21:12:37.610042: Step 590: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:38.209110: Step 600: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:38.210095: Step 600: Cross entropy = 0.032957
# INFO:tensorflow:2018-01-06 21:12:38.273429: Step 600: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:38.880065: Step 610: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:38.881064: Step 610: Cross entropy = 0.025099
# INFO:tensorflow:2018-01-06 21:12:38.947413: Step 610: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:39.545499: Step 620: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:39.546468: Step 620: Cross entropy = 0.026804
# INFO:tensorflow:2018-01-06 21:12:39.609356: Step 620: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:40.210161: Step 630: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:40.211194: Step 630: Cross entropy = 0.020443
# INFO:tensorflow:2018-01-06 21:12:40.276780: Step 630: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:40.869105: Step 640: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:40.870142: Step 640: Cross entropy = 0.020801
# INFO:tensorflow:2018-01-06 21:12:40.937209: Step 640: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:41.530747: Step 650: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:41.531825: Step 650: Cross entropy = 0.043844
# INFO:tensorflow:2018-01-06 21:12:41.595739: Step 650: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:42.200856: Step 660: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:42.201881: Step 660: Cross entropy = 0.018974
# INFO:tensorflow:2018-01-06 21:12:42.266874: Step 660: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:42.865494: Step 670: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:42.866457: Step 670: Cross entropy = 0.033165
# INFO:tensorflow:2018-01-06 21:12:42.929751: Step 670: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:43.526254: Step 680: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:43.527290: Step 680: Cross entropy = 0.020927
# INFO:tensorflow:2018-01-06 21:12:43.588015: Step 680: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:44.187370: Step 690: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:44.188356: Step 690: Cross entropy = 0.039048
# INFO:tensorflow:2018-01-06 21:12:44.250352: Step 690: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:44.851285: Step 700: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:44.852324: Step 700: Cross entropy = 0.027467
# INFO:tensorflow:2018-01-06 21:12:44.915151: Step 700: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:45.512010: Step 710: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:45.513003: Step 710: Cross entropy = 0.023325
# INFO:tensorflow:2018-01-06 21:12:45.576571: Step 710: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:46.179204: Step 720: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:46.180227: Step 720: Cross entropy = 0.020060
# INFO:tensorflow:2018-01-06 21:12:46.244158: Step 720: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:46.848391: Step 730: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:46.849365: Step 730: Cross entropy = 0.023898
# INFO:tensorflow:2018-01-06 21:12:46.914213: Step 730: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:47.513444: Step 740: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:47.514435: Step 740: Cross entropy = 0.042522
# INFO:tensorflow:2018-01-06 21:12:47.577525: Step 740: Validation accuracy = 96.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:48.180122: Step 750: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:48.181176: Step 750: Cross entropy = 0.028339
# INFO:tensorflow:2018-01-06 21:12:48.244437: Step 750: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:48.837293: Step 760: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:48.838288: Step 760: Cross entropy = 0.019639
# INFO:tensorflow:2018-01-06 21:12:48.901659: Step 760: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:49.492002: Step 770: Train accuracy = 99.0%
# INFO:tensorflow:2018-01-06 21:12:49.492998: Step 770: Cross entropy = 0.024327
# INFO:tensorflow:2018-01-06 21:12:49.556263: Step 770: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:50.150074: Step 780: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:50.151081: Step 780: Cross entropy = 0.022829
# INFO:tensorflow:2018-01-06 21:12:50.215229: Step 780: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:50.814363: Step 790: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:50.815352: Step 790: Cross entropy = 0.026816
# INFO:tensorflow:2018-01-06 21:12:50.877938: Step 790: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:51.476124: Step 800: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:51.477165: Step 800: Cross entropy = 0.026746
# INFO:tensorflow:2018-01-06 21:12:51.544120: Step 800: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:52.156671: Step 810: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:52.157713: Step 810: Cross entropy = 0.029096
# INFO:tensorflow:2018-01-06 21:12:52.218902: Step 810: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:52.819035: Step 820: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:52.820013: Step 820: Cross entropy = 0.036960
# INFO:tensorflow:2018-01-06 21:12:52.881601: Step 820: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:53.477525: Step 830: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:53.478598: Step 830: Cross entropy = 0.024669
# INFO:tensorflow:2018-01-06 21:12:53.539461: Step 830: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:54.133369: Step 840: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:54.134392: Step 840: Cross entropy = 0.033694
# INFO:tensorflow:2018-01-06 21:12:54.196758: Step 840: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:54.806948: Step 850: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:54.807920: Step 850: Cross entropy = 0.023042
# INFO:tensorflow:2018-01-06 21:12:54.871505: Step 850: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:55.465713: Step 860: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:55.466744: Step 860: Cross entropy = 0.026225
# INFO:tensorflow:2018-01-06 21:12:55.528067: Step 860: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:56.123389: Step 870: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:56.124358: Step 870: Cross entropy = 0.044974
# INFO:tensorflow:2018-01-06 21:12:56.186951: Step 870: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:56.795692: Step 880: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:56.796694: Step 880: Cross entropy = 0.039287
# INFO:tensorflow:2018-01-06 21:12:56.860420: Step 880: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:57.477620: Step 890: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:57.478666: Step 890: Cross entropy = 0.018105
# INFO:tensorflow:2018-01-06 21:12:57.542494: Step 890: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:58.142678: Step 900: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:58.143641: Step 900: Cross entropy = 0.016938
# INFO:tensorflow:2018-01-06 21:12:58.207578: Step 900: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:58.816819: Step 910: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:58.817829: Step 910: Cross entropy = 0.029742
# INFO:tensorflow:2018-01-06 21:12:58.881241: Step 910: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:12:59.469746: Step 920: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:12:59.470759: Step 920: Cross entropy = 0.029480
# INFO:tensorflow:2018-01-06 21:12:59.537337: Step 920: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:00.143439: Step 930: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:00.144481: Step 930: Cross entropy = 0.019483
# INFO:tensorflow:2018-01-06 21:13:00.205794: Step 930: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:00.811361: Step 940: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:00.812359: Step 940: Cross entropy = 0.011901
# INFO:tensorflow:2018-01-06 21:13:00.877540: Step 940: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:01.478885: Step 950: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:01.479890: Step 950: Cross entropy = 0.024044
# INFO:tensorflow:2018-01-06 21:13:01.542003: Step 950: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:02.169350: Step 960: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:02.170428: Step 960: Cross entropy = 0.020480
# INFO:tensorflow:2018-01-06 21:13:02.232165: Step 960: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:02.845695: Step 970: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:02.846685: Step 970: Cross entropy = 0.022514
# INFO:tensorflow:2018-01-06 21:13:02.910066: Step 970: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:03.502243: Step 980: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:03.503288: Step 980: Cross entropy = 0.026253
# INFO:tensorflow:2018-01-06 21:13:03.567997: Step 980: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:04.173053: Step 990: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:04.174060: Step 990: Cross entropy = 0.016693
# INFO:tensorflow:2018-01-06 21:13:04.241381: Step 990: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:04.843186: Step 1000: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:04.844187: Step 1000: Cross entropy = 0.020795
# INFO:tensorflow:2018-01-06 21:13:04.907022: Step 1000: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:05.521414: Step 1010: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:05.522435: Step 1010: Cross entropy = 0.028072
# INFO:tensorflow:2018-01-06 21:13:05.583664: Step 1010: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:06.176944: Step 1020: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:06.177960: Step 1020: Cross entropy = 0.031601
# INFO:tensorflow:2018-01-06 21:13:06.243162: Step 1020: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:06.858481: Step 1030: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:06.859482: Step 1030: Cross entropy = 0.012243
# INFO:tensorflow:2018-01-06 21:13:06.920845: Step 1030: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:07.524077: Step 1040: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:07.525078: Step 1040: Cross entropy = 0.012725
# INFO:tensorflow:2018-01-06 21:13:07.586088: Step 1040: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:08.191558: Step 1050: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:08.192615: Step 1050: Cross entropy = 0.014723
# INFO:tensorflow:2018-01-06 21:13:08.255634: Step 1050: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:08.865451: Step 1060: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:08.866506: Step 1060: Cross entropy = 0.016414
# INFO:tensorflow:2018-01-06 21:13:08.928670: Step 1060: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:09.533615: Step 1070: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:09.534618: Step 1070: Cross entropy = 0.012319
# INFO:tensorflow:2018-01-06 21:13:09.601249: Step 1070: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:10.287634: Step 1080: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:10.288755: Step 1080: Cross entropy = 0.016981
# INFO:tensorflow:2018-01-06 21:13:10.361703: Step 1080: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:11.002196: Step 1090: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:11.003193: Step 1090: Cross entropy = 0.012619
# INFO:tensorflow:2018-01-06 21:13:11.064317: Step 1090: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:11.665568: Step 1100: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:11.666527: Step 1100: Cross entropy = 0.018361
# INFO:tensorflow:2018-01-06 21:13:11.729649: Step 1100: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:12.327883: Step 1110: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:12.328931: Step 1110: Cross entropy = 0.011339
# INFO:tensorflow:2018-01-06 21:13:12.395169: Step 1110: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:12.988255: Step 1120: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:12.989256: Step 1120: Cross entropy = 0.017016
# INFO:tensorflow:2018-01-06 21:13:13.050593: Step 1120: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:13.651566: Step 1130: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:13.652624: Step 1130: Cross entropy = 0.018390
# INFO:tensorflow:2018-01-06 21:13:13.715974: Step 1130: Validation accuracy = 97.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:14.319042: Step 1140: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:14.320015: Step 1140: Cross entropy = 0.025952
# INFO:tensorflow:2018-01-06 21:13:14.381480: Step 1140: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:15.001524: Step 1150: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:15.002617: Step 1150: Cross entropy = 0.024469
# INFO:tensorflow:2018-01-06 21:13:15.067657: Step 1150: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:15.668425: Step 1160: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:15.669449: Step 1160: Cross entropy = 0.032731
# INFO:tensorflow:2018-01-06 21:13:15.732728: Step 1160: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:16.349309: Step 1170: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:16.350277: Step 1170: Cross entropy = 0.023475
# INFO:tensorflow:2018-01-06 21:13:16.416584: Step 1170: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:17.031343: Step 1180: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:17.032350: Step 1180: Cross entropy = 0.015106
# INFO:tensorflow:2018-01-06 21:13:17.093203: Step 1180: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:17.686739: Step 1190: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:17.687759: Step 1190: Cross entropy = 0.037047
# INFO:tensorflow:2018-01-06 21:13:17.750615: Step 1190: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:18.349204: Step 1200: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:18.350191: Step 1200: Cross entropy = 0.019697
# INFO:tensorflow:2018-01-06 21:13:18.411748: Step 1200: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:19.010960: Step 1210: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:19.011924: Step 1210: Cross entropy = 0.022489
# INFO:tensorflow:2018-01-06 21:13:19.075195: Step 1210: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:19.676267: Step 1220: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:19.677236: Step 1220: Cross entropy = 0.032204
# INFO:tensorflow:2018-01-06 21:13:19.740447: Step 1220: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:20.349404: Step 1230: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:20.350400: Step 1230: Cross entropy = 0.026712
# INFO:tensorflow:2018-01-06 21:13:20.413558: Step 1230: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:21.030258: Step 1240: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:21.031248: Step 1240: Cross entropy = 0.025894
# INFO:tensorflow:2018-01-06 21:13:21.095285: Step 1240: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:21.720927: Step 1250: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:21.721993: Step 1250: Cross entropy = 0.020273
# INFO:tensorflow:2018-01-06 21:13:21.785723: Step 1250: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:22.403158: Step 1260: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:22.404175: Step 1260: Cross entropy = 0.019566
# INFO:tensorflow:2018-01-06 21:13:22.469711: Step 1260: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:23.082456: Step 1270: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:23.083462: Step 1270: Cross entropy = 0.011942
# INFO:tensorflow:2018-01-06 21:13:23.146547: Step 1270: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:23.760442: Step 1280: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:23.761450: Step 1280: Cross entropy = 0.017045
# INFO:tensorflow:2018-01-06 21:13:23.824866: Step 1280: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:24.440093: Step 1290: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:24.441127: Step 1290: Cross entropy = 0.021031
# INFO:tensorflow:2018-01-06 21:13:24.504875: Step 1290: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:25.120074: Step 1300: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:25.121121: Step 1300: Cross entropy = 0.027326
# INFO:tensorflow:2018-01-06 21:13:25.184790: Step 1300: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:25.795498: Step 1310: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:25.796517: Step 1310: Cross entropy = 0.025378
# INFO:tensorflow:2018-01-06 21:13:25.859875: Step 1310: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:26.456811: Step 1320: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:26.457797: Step 1320: Cross entropy = 0.008287
# INFO:tensorflow:2018-01-06 21:13:26.518923: Step 1320: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:27.130223: Step 1330: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:27.131258: Step 1330: Cross entropy = 0.012987
# INFO:tensorflow:2018-01-06 21:13:27.194005: Step 1330: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:27.798634: Step 1340: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:27.799634: Step 1340: Cross entropy = 0.018522
# INFO:tensorflow:2018-01-06 21:13:27.862612: Step 1340: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:28.466861: Step 1350: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:28.467868: Step 1350: Cross entropy = 0.010087
# INFO:tensorflow:2018-01-06 21:13:28.531458: Step 1350: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:29.134616: Step 1360: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:29.135619: Step 1360: Cross entropy = 0.016181
# INFO:tensorflow:2018-01-06 21:13:29.199283: Step 1360: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:29.799661: Step 1370: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:29.800684: Step 1370: Cross entropy = 0.017118
# INFO:tensorflow:2018-01-06 21:13:29.863148: Step 1370: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:30.460495: Step 1380: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:30.461496: Step 1380: Cross entropy = 0.014756
# INFO:tensorflow:2018-01-06 21:13:30.524777: Step 1380: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:31.161481: Step 1390: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:31.162491: Step 1390: Cross entropy = 0.013547
# INFO:tensorflow:2018-01-06 21:13:31.226188: Step 1390: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:31.836216: Step 1400: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:31.837213: Step 1400: Cross entropy = 0.019818
# INFO:tensorflow:2018-01-06 21:13:31.899933: Step 1400: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:32.512974: Step 1410: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:32.513986: Step 1410: Cross entropy = 0.014588
# INFO:tensorflow:2018-01-06 21:13:32.575235: Step 1410: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:33.192619: Step 1420: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:33.193634: Step 1420: Cross entropy = 0.014419
# INFO:tensorflow:2018-01-06 21:13:33.255474: Step 1420: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:33.860480: Step 1430: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:33.861476: Step 1430: Cross entropy = 0.012994
# INFO:tensorflow:2018-01-06 21:13:33.923635: Step 1430: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:34.540162: Step 1440: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:34.541130: Step 1440: Cross entropy = 0.022420
# INFO:tensorflow:2018-01-06 21:13:34.604572: Step 1440: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:35.206929: Step 1450: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:35.207971: Step 1450: Cross entropy = 0.011368
# INFO:tensorflow:2018-01-06 21:13:35.271269: Step 1450: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:35.875664: Step 1460: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:35.876701: Step 1460: Cross entropy = 0.013010
# INFO:tensorflow:2018-01-06 21:13:35.939783: Step 1460: Validation accuracy = 99.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:36.552260: Step 1470: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:36.553251: Step 1470: Cross entropy = 0.010947
# INFO:tensorflow:2018-01-06 21:13:36.614977: Step 1470: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:37.207733: Step 1480: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:37.208766: Step 1480: Cross entropy = 0.010716
# INFO:tensorflow:2018-01-06 21:13:37.269351: Step 1480: Validation accuracy = 98.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:37.870505: Step 1490: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:37.871541: Step 1490: Cross entropy = 0.019180
# INFO:tensorflow:2018-01-06 21:13:37.933116: Step 1490: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:38.534512: Step 1500: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:38.535490: Step 1500: Cross entropy = 0.011464
# INFO:tensorflow:2018-01-06 21:13:38.596718: Step 1500: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:39.212018: Step 1510: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:39.213090: Step 1510: Cross entropy = 0.010062
# INFO:tensorflow:2018-01-06 21:13:39.275231: Step 1510: Validation accuracy = 100.0% (N=100)
# INFO:tensorflow:2018-01-06 21:13:39.868738: Step 1520: Train accuracy = 100.0%
# INFO:tensorflow:2018-01-06 21:13:39.869723: Step 1520: Cross entropy = 0.011523
# INFO:tensorflow:2018-01-06 21:13:39.935085: Step 1520: Validation accuracy = 99.0% (N=100)
